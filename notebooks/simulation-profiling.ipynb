# %%
import tomllib
from cProfile import Profile
from pstats import SortKey, Stats

import AEIC.trajectories.builders as tb
from AEIC.config import Config, config
from AEIC.missions import Mission
from AEIC.performance.models import PerformanceModel

# %%
Config.load();

# %%
performance_model = PerformanceModel.load(
    config.file_location('performance/sample_performance_model.toml')
)

# %%
missions_file = config.file_location('missions/sample_missions_10.toml')
with open(missions_file, 'rb') as f:
    mission_dict = tomllib.load(f)
sample_missions = Mission.from_toml(mission_dict)

# %%
builder = tb.LegacyBuilder(options=tb.Options(iterate_mass=False))
mis = sample_missions[0]

# %%
traj_cache_fill = builder.fly(performance_model, mis)
with Profile() as profile:
    traj = builder.fly(performance_model, mis)
    Stats(profile).sort_stats(SortKey.CALLS).print_stats()
    profile.dump_stats('test.prof')
# Out:
#          223109 function calls (222596 primitive calls) in 0.284 seconds
#
#    Ordered by: call count
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#     18336    0.003    0.000    0.003    0.000 {built-in method builtins.len}
#     17424    0.035    0.000    0.035    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#     17424    0.023    0.000    0.068    0.000 /home/iross/work/mit/code/AEIC/.venv/lib/python3.13/site-packages/numpy/_core/fromnumeric.py:89(_wrapreduction_any_all)
#     17424    0.004    0.000    0.004    0.000 {method 'items' of 'dict' objects}
#     14418    0.011    0.000    0.065    0.000 /home/iross/work/mit/code/AEIC/.venv/lib/python3.13/site-packages/numpy/_core/fromnumeric.py:2589(all)
#     14418    0.002    0.000    0.002    0.000 /home/iross/work/mit/code/AEIC/.venv/lib/python3.13/site-packages/numpy/_core/fromnumeric.py:2584(_all_dispatcher)
#     13829    0.004    0.000    0.004    0.000 {built-in method numpy.asarray}
# 10612/10100    0.003    0.000    0.004    0.000 {built-in method builtins.hasattr}
#      8112    0.001    0.000    0.001    0.000 /home/iross/work/mit/code/AEIC/src/AEIC/trajectories/trajectory.py:211(__getattr__)
#      4806    0.001    0.000    0.001    0.000 {built-in method numpy.ascontiguousarray}
#      4806    0.001    0.000    0.001    0.000 {method 'append' of 'list' objects}
#      4757    0.001    0.000    0.001    0.000 {built-in method builtins.getattr}
#      4509    0.001    0.000    0.001    0.000 {built-in method builtins.issubclass}
#      3810    0.003    0.000    0.003    0.000 {built-in method numpy.array}
#      3600    0.005    0.000    0.012    0.000 {method 'all' of 'numpy.generic' objects}
#      3600    0.001    0.000    0.007    0.000 /home/iross/work/mit/code/AEIC/.venv/lib/python3.13/site-packages/numpy/_core/_methods.py:66(_all)
#      3009    0.002    0.000    0.002    0.000 {method 'reshape' of 'numpy.ndarray' objects}
#      3006    0.005    0.000    0.007    0.000 /home/iross/work/mit/code/AEIC/.venv/lib/python3.13/site-packages/scipy/interpolate/_rgi.py:40(_check_dimensionality)
#      3006    0.020    0.000    0.046    0.000 /home/iross/work/mit/code/AEIC/.venv/lib/python3.13/site-packages/scipy/interpolate/_rgi.py:17(_check_points)
#      3006    0.003    0.000    0.016    0.000 /home/iross/work/mit/code/AEIC/.venv/lib/python3.13/site-packages/numpy/_core/fromnumeric.py:2477(any)
#      3006    0.000    0.000    0.000    0.000 /home/iross/work/mit/code/AEIC/.venv/lib/python3.13/site-packages/numpy/_core/fromnumeric.py:2472(_any_dispatcher)
#      3006    0.000    0.000    0.000    0.000 /home/iross/work/mit/code/AEIC/.venv/lib/python3.13/site-packages/numpy/_core/multiarray.py:115(empty_like)
#      3006    0.002    0.000    0.003    0.000 /home/iross/work/mit/code/AEIC/.venv/lib/python3.13/site-packages/numpy/_core/numerictypes.py:293(issubclass_)
#      1517    0.001    0.000    0.001    0.000 {built-in method numpy.zeros}
#      1508    0.000    0.000    0.000    0.000 /home/iross/work/mit/code/AEIC/.venv/lib/python3.13/site-packages/numpy/_core/multiarray.py:588(can_cast)
#      1503    0.004    0.000    0.044    0.000 /home/iross/work/mit/code/AEIC/.venv/lib/python3.13/site-packages/scipy/interpolate/_rgi.py:275(__init__)
#      1503    0.014    0.000    0.116    0.000 /home/iross/work/mit/code/AEIC/.venv/lib/python3.13/site-packages/scipy/interpolate/_rgi.py:342(__call__)
#      1503    0.027    0.000    0.055    0.000 /home/iross/work/mit/code/AEIC/.venv/lib/python3.13/site-packages/scipy/interpolate/_rgi.py:451(_prepare_xi)
#      1503    0.031    0.000    0.252    0.000 /home/iross/work/mit/code/AEIC/.venv/lib/python3.13/site-packages/scipy/interpolate/_rgi.py:604(interpn)
#      1503    0.001    0.000    0.004    0.000 /home/iross/work/mit/code/AEIC/.venv/lib/python3.13/site-packages/scipy/interpolate/_rgi.py:315(_check_dimensionality)
#      1503    0.002    0.000    0.009    0.000 /home/iross/work/mit/code/AEIC/.venv/lib/python3.13/site-packages/scipy/interpolate/_rgi.py:321(_check_values)
#      1503    0.014    0.000    0.021    0.000 /home/iross/work/mit/code/AEIC/.venv/lib/python3.13/site-packages/scipy/interpolate/_rgi.py:591(_find_indices)
#      1503    0.003    0.000    0.005    0.000 /home/iross/work/mit/code/AEIC/.venv/lib/python3.13/site-packages/scipy/interpolate/_rgi.py:332(_check_fill_value)
#      1503    0.000    0.000    0.000    0.000 /home/iross/work/mit/code/AEIC/.venv/lib/python3.13/site-packages/numpy/_core/numeric.py:92(_zeros_like_dispatcher)
#      1503    0.002    0.000    0.006    0.000 /home/iross/work/mit/code/AEIC/.venv/lib/python3.13/site-packages/numpy/_core/numerictypes.py:475(issubdtype)
#      1503    0.006    0.000    0.007    0.000 /home/iross/work/mit/code/AEIC/.venv/lib/python3.13/site-packages/numpy/_core/numeric.py:98(zeros_like)
#      1503    0.000    0.000    0.000    0.000 /home/iross/work/mit/code/AEIC/.venv/lib/python3.13/site-packages/numpy/_core/multiarray.py:1106(copyto)
#      1495    0.000    0.000    0.000    0.000 /home/iross/work/mit/code/AEIC/src/AEIC/trajectories/ground_track.py:76(__contains__)
#      1160    0.001    0.000    0.001    0.000 /home/iross/work/mit/code/AEIC/src/AEIC/trajectories/builders/base.py:96(__getattr__)
#      1030    0.000    0.000    0.001    0.000 /opt/pyenv/versions/3.13.11/lib/python3.13/enum.py:1312(__hash__)
#      1030    0.000    0.000    0.000    0.000 {built-in method builtins.hash}
#      1000    0.001    0.000    0.001    0.000 /home/iross/work/mit/code/AEIC/.venv/lib/python3.13/site-packages/numpy/_core/_exceptions.py:40(__init__)
#      1000    0.000    0.000    0.000    0.000 /home/iross/work/mit/code/AEIC/.venv/lib/python3.13/site-packages/numpy/_core/_exceptions.py:33(__init__)
#       900    0.001    0.000    0.001    0.000 {built-in method numpy.empty}
#       900    0.002    0.000    0.002    0.000 /home/iross/work/mit/code/AEIC/.venv/lib/python3.13/site-packages/numpy/lib/_stride_tricks_impl.py:413(_broadcast_shape)
#       900    0.003    0.000    0.006    0.000 /home/iross/work/mit/code/AEIC/.venv/lib/python3.13/site-packages/numpy/lib/_stride_tricks_impl.py:481(broadcast_arrays)
#       900    0.000    0.000    0.000    0.000 /home/iross/work/mit/code/AEIC/.venv/lib/python3.13/site-packages/numpy/lib/_stride_tricks_impl.py:477(_broadcast_arrays_dispatcher)
#       897    0.000    0.000    0.001    0.000 /home/iross/work/mit/code/AEIC/src/AEIC/trajectories/ground_track.py:93(lookup_waypoint)
#       897    0.000    0.000    0.000    0.000 {built-in method _bisect.bisect_left}
#       603    0.013    0.000    0.014    0.000 /home/iross/work/mit/code/AEIC/.venv/lib/python3.13/site-packages/scipy/interpolate/_rgi.py:479(_evaluate_linear)
#       523    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#       506    0.001    0.000    0.003    0.000 /home/iross/work/mit/code/AEIC/.venv/lib/python3.13/site-packages/pydantic/main.py:999(__getattr__)
#       506    0.001    0.000    0.002    0.000 /home/iross/work/mit/code/AEIC/.venv/lib/python3.13/site-packages/pydantic/fields.py:1425(__getattr__)
#       501    0.004    0.000    0.257    0.001 /home/iross/work/mit/code/AEIC/src/AEIC/performance/models/legacy.py:121(__call__)
#       501    0.001    0.000    0.268    0.001 /home/iross/work/mit/code/AEIC/src/AEIC/performance/models/legacy.py:354(evaluate_impl)
#       501    0.005    0.000    0.264    0.001 /home/iross/work/mit/code/AEIC/src/AEIC/performance/models/legacy.py:270(interpolate)
#       501    0.000    0.000    0.268    0.001 /home/iross/work/mit/code/AEIC/src/AEIC/performance/models/base.py:213(_evaluate_checked)
#       501    0.000    0.000    0.269    0.001 /home/iross/work/mit/code/AEIC/src/AEIC/performance/models/base.py:200(evaluate)
#       300    0.000    0.000    0.000    0.000 <string>:2(__init__)
#       300    0.000    0.000    0.000    0.000 /home/iross/work/mit/code/AEIC/src/AEIC/trajectories/ground_track.py:43(__post_init__)
#       300    0.001    0.000    0.001    0.000 /home/iross/work/mit/code/AEIC/.venv/lib/python3.13/site-packages/pyproj/geod.py:331(inv)
#       299    0.001    0.000    0.004    0.000 /home/iross/work/mit/code/AEIC/src/AEIC/trajectories/ground_track.py:103(location)
#       299    0.001    0.000    0.005    0.000 /home/iross/work/mit/code/AEIC/src/AEIC/trajectories/ground_track.py:147(step)
#       299    0.001    0.000    0.001    0.000 /home/iross/work/mit/code/AEIC/.venv/lib/python3.13/site-packages/pyproj/geod.py:239(fwd)
#       150    0.000    0.000    0.000    0.000 /home/iross/work/mit/code/AEIC/src/AEIC/trajectories/dimensions.py:62(__contains__)
#        86    0.000    0.000    0.000    0.000 /home/iross/work/mit/code/AEIC/src/AEIC/trajectories/field_sets.py:385(__getitem__)
#        84    0.000    0.000    0.000    0.000 <frozen _collections_abc>:897(__iter__)
#        27    0.000    0.000    0.000    0.000 /home/iross/work/mit/code/AEIC/src/AEIC/trajectories/field_sets.py:132(empty)
#        17    0.000    0.000    0.000    0.000 /home/iross/work/mit/code/AEIC/src/AEIC/trajectories/builders/base.py:149(n_climb)
#        12    0.000    0.000    0.000    0.000 /opt/pyenv/versions/3.13.11/lib/python3.13/enum.py:199(__get__)
#        12    0.000    0.000    0.000    0.000 /home/iross/work/mit/code/AEIC/src/AEIC/trajectories/phase.py:43(method_name)
#        12    0.000    0.000    0.000    0.000 /opt/pyenv/versions/3.13.11/lib/python3.13/enum.py:1332(name)
#        12    0.000    0.000    0.000    0.000 {method 'lower' of 'str' objects}
#        10    0.000    0.000    0.000    0.000 /opt/pyenv/versions/3.13.11/lib/python3.13/enum.py:799(<genexpr>)
#         9    0.000    0.000    0.000    0.000 /home/iross/work/mit/code/AEIC/src/AEIC/trajectories/trajectory.py:225(__setattr__)
#         8    0.000    0.000    0.000    0.000 {method 'astype' of 'numpy.ndarray' objects}
#         7    0.000    0.000    0.000    0.000 /home/iross/work/mit/code/AEIC/src/AEIC/trajectories/builders/base.py:154(n_cruise)
#         5    0.000    0.000    0.000    0.000 /home/iross/work/mit/code/AEIC/src/AEIC/trajectories/field_sets.py:177(_cast)
#         5    0.000    0.000    0.000    0.000 /home/iross/work/mit/code/AEIC/src/AEIC/trajectories/field_sets.py:201(convert_in)
#         5    0.000    0.000    0.000    0.000 /home/iross/work/mit/code/AEIC/src/AEIC/performance/models/legacy.py:349(performance_table)
#         5    0.000    0.000    0.000    0.000 {method 'item' of 'numpy.ndarray' objects}
#         4    0.000    0.000    0.000    0.000 /home/iross/work/mit/code/AEIC/.venv/lib/python3.13/site-packages/pyproj/utils.py:89(_copytobuffer)
#         4    0.000    0.000    0.000    0.000 /home/iross/work/mit/code/AEIC/src/AEIC/trajectories/builders/base.py:118(__setattr__)
#         4    0.000    0.000    0.000    0.000 /home/iross/work/mit/code/AEIC/src/AEIC/performance/models/base.py:136(maximum_altitude)
#         4    0.000    0.000    0.000    0.000 {built-in method builtins.max}
#         3    0.000    0.000    0.000    0.000 /home/iross/work/mit/code/AEIC/.venv/lib/python3.13/site-packages/numpy/_core/function_base.py:26(linspace)
#         3    0.000    0.000    0.000    0.000 /home/iross/work/mit/code/AEIC/.venv/lib/python3.13/site-packages/pyproj/utils.py:146(_convertback)
#         3    0.000    0.000    0.000    0.000 {method 'as_arrays' of 'numpy._core._multiarray_umath._array_converter' objects}
#         3    0.000    0.000    0.000    0.000 {method 'result_type' of 'numpy._core._multiarray_umath._array_converter' objects}
#         3    0.000    0.000    0.000    0.000 {method 'wrap' of 'numpy._core._multiarray_umath._array_converter' objects}
#         3    0.000    0.000    0.000    0.000 {built-in method numpy.arange}
#         3    0.000    0.000    0.000    0.000 /home/iross/work/mit/code/AEIC/.venv/lib/python3.13/site-packages/numpy/_core/fromnumeric.py:3519(_ndim_dispatcher)
#         3    0.000    0.000    0.000    0.000 /home/iross/work/mit/code/AEIC/.venv/lib/python3.13/site-packages/numpy/_core/function_base.py:21(_linspace_dispatcher)
#         3    0.000    0.000    0.000    0.000 /home/iross/work/mit/code/AEIC/.venv/lib/python3.13/site-packages/numpy/_core/numeric.py:1964(isscalar)
#         3    0.000    0.000    0.000    0.000 /home/iross/work/mit/code/AEIC/.venv/lib/python3.13/site-packages/numpy/_core/fromnumeric.py:3523(ndim)
#         3    0.000    0.000    0.000    0.000 /home/iross/work/mit/code/AEIC/src/AEIC/trajectories/field_sets.py:389(__iter__)
#         3    0.000    0.000    0.000    0.000 {method 'tolist' of 'array.array' objects}
#         3    0.000    0.000    0.000    0.000 <frozen _collections_abc>:827(items)
#         3    0.000    0.000    0.000    0.000 <frozen _collections_abc>:850(__init__)
#         3    0.000    0.000    0.000    0.000 {built-in method builtins.iter}
#         3    0.000    0.000    0.000    0.000 {built-in method _operator.index}
#         2    0.000    0.000    0.000    0.000 /home/iross/work/mit/code/AEIC/src/AEIC/trajectories/trajectory.py:252(copy_point)
#       2/1    0.000    0.000    0.283    0.283 /home/iross/work/mit/code/AEIC/src/AEIC/trajectories/builders/base.py:164(fly)
#         2    0.003    0.001    0.105    0.053 /home/iross/work/mit/code/AEIC/src/AEIC/trajectories/builders/legacy.py:249(_fly_level_change)
#         2    0.000    0.000    0.000    0.000 /home/iross/work/mit/code/AEIC/src/AEIC/performance/models/legacy.py:344(maximum_mass)
#         2    0.000    0.000    0.000    0.000 /home/iross/work/mit/code/AEIC/src/AEIC/types/spatial.py:28(location)
#         2    0.000    0.000    0.000    0.000 /home/iross/work/mit/code/AEIC/src/AEIC/trajectories/ground_track.py:88(total_distance)
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.min}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.setattr}
#         1    0.000    0.000    0.000    0.000 /opt/pyenv/versions/3.13.11/lib/python3.13/pstats.py:118(init)
#         1    0.000    0.000    0.000    0.000 /opt/pyenv/versions/3.13.11/lib/python3.13/pstats.py:137(load_stats)
#         1    0.000    0.000    0.000    0.000 /home/iross/work/mit/code/AEIC/src/AEIC/trajectories/ground_track.py:52(__init__)
#         1    0.000    0.000    0.000    0.000 /home/iross/work/mit/code/AEIC/src/AEIC/trajectories/trajectory.py:152(__init__)
#         1    0.001    0.001    0.062    0.062 /home/iross/work/mit/code/AEIC/src/AEIC/trajectories/builders/legacy.py:364(fly_cruise)
#         1    0.000    0.000    0.283    0.283 /home/iross/work/mit/code/AEIC/src/AEIC/trajectories/builders/base.py:288(_fly_iteration)
#         1    0.000    0.000    0.000    0.000 /home/iross/work/mit/code/AEIC/src/AEIC/trajectories/builders/legacy.py:41(__init__)
#         1    0.000    0.000    0.001    0.001 /home/iross/work/mit/code/AEIC/src/AEIC/trajectories/builders/legacy.py:172(calc_starting_mass)
#         1    0.000    0.000    0.000    0.000 /home/iross/work/mit/code/AEIC/src/AEIC/trajectories/builders/base.py:138(n_total)
#         1    0.000    0.000    0.000    0.000 /home/iross/work/mit/code/AEIC/src/AEIC/trajectories/builders/base.py:159(n_descent)
#         1    0.000    0.000    0.097    0.097 /home/iross/work/mit/code/AEIC/src/AEIC/trajectories/builders/legacy.py:241(fly_descent)
#         1    0.002    0.002    0.124    0.124 /home/iross/work/mit/code/AEIC/src/AEIC/trajectories/builders/legacy.py:233(fly_climb)
#         1    0.000    0.000    0.000    0.000 /home/iross/work/mit/code/AEIC/src/AEIC/performance/models/legacy.py:337(empty_mass)
#         1    0.000    0.000    0.000    0.000 /home/iross/work/mit/code/AEIC/src/AEIC/performance/models/base.py:144(maximum_payload)
#         1    0.000    0.000    0.000    0.000 /home/iross/work/mit/code/AEIC/src/AEIC/trajectories/ground_track.py:65(great_circle)
#         1    0.000    0.000    0.000    0.000 /home/iross/work/mit/code/AEIC/src/AEIC/trajectories/ground_track.py:80(__getitem__)
#         1    0.000    0.000    0.000    0.000 /opt/pyenv/versions/3.13.11/lib/python3.13/cProfile.py:54(create_stats)
#         1    0.000    0.000    0.000    0.000 /opt/pyenv/versions/3.13.11/lib/python3.13/pstats.py:108(__init__)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.000    0.000 /opt/pyenv/versions/3.13.11/lib/python3.13/enum.py:795(__iter__)
#         1    0.000    0.000    0.000    0.000 {method 'values' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.sum}
#         1    0.000    0.000    0.000    0.000 {built-in method posix.getppid}
